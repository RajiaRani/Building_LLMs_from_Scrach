# %%
import torch
import torch.nn as nn

# %%
inputs = torch.tensor([
    [0.43, 0.15, 0.89, 0.55, 0.87, 0.66], # Your
    [0.57, 0.85, 0.64,0.22, 0.58, 0.33 ], # starts
    [0.77, 0.25, 0.10, 0.05, 0.80, 0.55] # step
])

# %%
d_in = inputs.shape[1]
d_out = d_in
print(d_out)
# Out:
# 6

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 W_query = nn.Linear(d_in,d_out)
# ----> 2 print(W_query[1])
#
# TypeError: 'Linear' object is not subscriptable
