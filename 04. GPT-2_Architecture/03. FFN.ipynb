# %%
import torch
import torch.nn as nn

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # Vocabulary size
    "context_length": 1024, # Context length
    "emb_dim": 768,         # Embedding dimension
    "n_heads": 12,          # Number of attention heads
    "n_layers": 12,         # Number of layers
    "drop_rate": 0.1,       # Dropout rate
    "qkv_bias": False       # Query-Key-Value bias
}

# %%
class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]), # expansion 
            nn.GELU(),                                        # Gelu activation
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]) # contraction
        )

    def forward(self, x):
        return self.layers(x)

# %%
ffn = FeedForward(GPT_CONFIG_124M)
x = torch.rand(2, 3, 768) #(batch_size, context_length, emb_dim)
output = ffn(x)
print(output.shape)
print(output)
# Out:
# torch.Size([2, 3, 768])
# tensor([[[ 0.0024,  0.0070, -0.0807,  ..., -0.1917,  0.0226,  0.0465],
#          [ 0.0311,  0.0356,  0.0415,  ..., -0.2690, -0.0032,  0.1286],
#          [ 0.0598, -0.0843,  0.0474,  ..., -0.3073,  0.0075,  0.0529]],
#
#         [[-0.0347, -0.0271, -0.0293,  ..., -0.2211, -0.0642,  0.0112],
#          [-0.0210,  0.0120,  0.0113,  ..., -0.2335, -0.0009, -0.0172],
#          [ 0.0365,  0.0122,  0.0867,  ..., -0.2605, -0.1152,  0.0064]]],
#        grad_fn=<ViewBackward0>)
